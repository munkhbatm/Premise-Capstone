# %%
import numpy as np 
import pandas as pd 
from datetime import datetime, date, time
from datetime import timedelta
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
# %matplotlib inline
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

# set float display default
pd.set_option('display.float_format', lambda x: '%.2f' % x)

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
# Out:
# ...
#      |████████████████████████████████| 13.2 MB 6.3 MB/s eta 0:00:01     |█████████████████████████████▌  | 12.2 MB 6.3 MB/s eta 0:00:01
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=e32b9e1bb7dafa8b82cfa3c8719fec513305e6d126f652eb7b8f19ea0dbb526c
#   Stored in directory: /Users/Caspar/Library/Caches/pip/wheels/c4/a7/48/0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset = pd.read_csv('covid-19.csv')

# %%
dataset = dataset.iloc[:,9:]

# %%
dataset.shape
# Out:
# (2866985, 80)

# %%
dataset.columns
# Out:
# Index(['campaign_name', 'project_id', 'project_name', 'organization_id',
#        'gender', 'age', 'geography', 'financial_situation', 'education',
#        'employment_status', 'ethnicity', 'religion', 'batch_date',
#        'location_feature_id', 'location_feature_name', 'observation_lat',
#        'observation_lon', 'HASC_code', 'L0_name', 'L1_name', 'L2_name',
#        'intro_input',
#        'the_following_questions_will_ask_you_about_the_spread_of_covid_19_in_your_area',
#        'how_concerned_are_you_about_the_spread_of_covid_19_in_your_community',
#        'have_you_personally_contracted_covid_19',
#        'did_you_seek_medical_care_to_treat_covid_19',
#        'how_satisfied_were_you_with_the_level_of_care_you_received',
#        'how_confident_are_you_that_you_are_immune_should_a_"second_wave"_emerge_in_the_future',
#        'why_were_you_not_tested',
#        'how_concerned_are_you_that_you_personally_will_contract_covid_19',
# ...

# %%
dataset.head()
# Out:
#         campaign_name        project_id project_name organization_id gender  \
# 0  bj_covid-19-impact  6055346049384448     COVID-19         premise   Male
# 1  bj_covid-19-impact  6055346049384448     COVID-19         premise   Male
# 2  bj_covid-19-impact  6055346049384448     COVID-19         premise   Male
# 3  bj_covid-19-impact  6055346049384448     COVID-19         premise   Male
# 4  bj_covid-19-impact  6055346049384448     COVID-19         premise   Male
#
#                   age            geography  \
# 0  16 to 25 years old                Rural
# 1  16 to 25 years old                Rural
# 2  16 to 25 years old                Rural
# 3  16 to 25 years old  Suburban/Peri-urban
# 4  16 to 25 years old                Rural
#
#                                  financial_situation              education  \
# 0  I can afford food and regular expenses, but no...  College or university
# 1  I can afford food and regular expenses, and bu...  College or university
# ...

# %%
dataset['L0_name'].value_counts()
# Out:
# Philippines     420096
# Afghanistan     210989
# Venezuela       120919
# Mali            103844
# Brazil          101269
#                  ...
# Turkmenistan         1
# Bulgaria             1
# Togo                 1
# Gabon                1
# Djibouti             1
# Name: L0_name, Length: 128, dtype: int64

# %%
data_Phi = dataset[dataset['L0_name']=='Philippines']

# %%
data_Phi.shape
# Out:
# (420096, 80)

# %%
data_Phi['batch_date']=pd.to_datetime(data_Phi['batch_date'])
# Out:
# <ipython-input-22-ab21c5e80b54>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Phi['batch_date']=pd.to_datetime(data_Phi['batch_date'])

# %%
data_Phi['batch_date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
data_Phi['how_concerned_are_you_about_your_access_to_adequate_health_care_services_should_you_contract_covid_19'].value_counts()
# Out:
# Very concerned                       134254
# Concerned                             91599
# Neither concerned nor unconcerned     45389
# Unconcerned                            2470
# Very unconcerned                       1584
# Name: how_concerned_are_you_about_your_access_to_adequate_health_care_services_should_you_contract_covid_19, dtype: int64

# %%
scale_1 = {'Very concerned':5, 'Concerned':4, 'Neither concerned nor unconcerned':3,'Unconcerned':2,'Very unconcerned':1}

# Map feature values to scale
data_Phi['how_concerned_are_you_about_your_access_to_adequate_health_care_services_should_you_contract_covid_19'] 
= data_Phi['how_concerned_are_you_about_your_access_to_adequate_health_care_services_should_you_contract_covid_19'].replace(scale_mapper)
# Out:
#   File "<ipython-input-18-0e1c34532462>", line 5
#     = data_Phi['how_concerned_are_you_about_your_access_to_adequate_health_care_services_should_you_contract_covid_19'].replace(scale_mapper)
#     ^
# SyntaxError: invalid syntax

# %%
data_Phi['how_concerned_are_you_about_your_access_to_adequate_health_care_services_should_you_contract_covid_19'].value_counts()
# Out:
# 5.00    134254
# 4.00     91599
# 3.00     45389
# 2.00      2470
# 1.00      1584
# Name: how_concerned_are_you_about_your_access_to_adequate_health_care_services_should_you_contract_covid_19, dtype: int64

# %%
data_Phi['how_concerned_are_you_about_the_spread_of_covid_19_in_your_community'].value_counts()
# Out:
# Very concerned                       224338
# Concerned                            125727
# Neither concerned nor unconcerned     63701
# Unconcerned                            4230
# Very unconcerned                       2099
# Name: how_concerned_are_you_about_the_spread_of_covid_19_in_your_community, dtype: int64

# %%
data_Phi['how_concerned_are_you_about_the_spread_of_covid_19_in_your_community']=data_Phi['how_concerned_are_you_about_the_spread_of_covid_19_in_your_community'].replace(scale_mapper)
# Out:
# <ipython-input-30-06eff03a4bb6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Phi['how_concerned_are_you_about_the_spread_of_covid_19_in_your_community']=data_Phi['how_concerned_are_you_about_the_spread_of_covid_19_in_your_community'].replace(scale_mapper)

# %%
data_Phi['how_concerned_are_you_about_the_spread_of_covid_19_in_your_community'].value_counts()
# Out:
# 5.00    224338
# 4.00    125727
# 3.00     63701
# 2.00      4230
# 1.00      2099
# Name: how_concerned_are_you_about_the_spread_of_covid_19_in_your_community, dtype: int64

# %%
scale_1 = {'Very concerned':5, 
                'Concerned':4, 
                'Neither concerned nor unconcerned':3,
                'Unconcerned':2,
                'Very unconcerned':1}

# %%
data_Phi['has_your_income_been_at_all_affected_by_the_covid_19_pandemic'].value_counts()
# Out:
# Yes, I have seen a reduction in my paycheck/hours/sales    181079
# Yes, I have been laid off or have otherwise lost my job    120237
# No, not at all                                             118780
# Name: has_your_income_been_at_all_affected_by_the_covid_19_pandemic, dtype: int64

# %%
scale_2 ={'Yes, I have been laid off or have otherwise lost my job':3,
          'Yes, I have seen a reduction in my paycheck/hours/sales':2,
          'No, not at all':1}
data_Phi['has_your_income_been_at_all_affected_by_the_covid_19_pandemic'] = data_Phi['has_your_income_been_at_all_affected_by_the_covid_19_pandemic'].replace(scale_2)
# Out:
# <ipython-input-33-07313c049637>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Phi['has_your_income_been_at_all_affected_by_the_covid_19_pandemic'] = data_Phi['has_your_income_been_at_all_affected_by_the_covid_19_pandemic'].replace(scale_2)

# %%
data_Phi['has_your_income_been_at_all_affected_by_the_covid_19_pandemic'].value_counts()
# Out:
# 2    181079
# 3    120237
# 1    118780
# Name: has_your_income_been_at_all_affected_by_the_covid_19_pandemic, dtype: int64

# %%
data_Phi['how_difficult_has_it_been_for_you_to_find_groceries_and_other_items'].value_counts()
# Out:
# Neither difficult nor easy    179712
# Difficult                     100392
# Easy                           71438
# Very difficult                 41827
# Very easy                      26727
# Name: how_difficult_has_it_been_for_you_to_find_groceries_and_other_items, dtype: int64

# %%
scale_3 = {'Very difficult':5,
          'Difficult':4,
          'Neither difficult nor easy':3,
          'Easy':2,
          'Very easy':1}
data_Phi['how_difficult_has_it_been_for_you_to_find_groceries_and_other_items']=data_Phi['how_difficult_has_it_been_for_you_to_find_groceries_and_other_items'].replace(scale_3)
# Out:
# <ipython-input-36-cc7d21881dbd>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Phi['how_difficult_has_it_been_for_you_to_find_groceries_and_other_items']=data_Phi['how_difficult_has_it_been_for_you_to_find_groceries_and_other_items'].replace(scale_3)

# %%
data_Phi['how_difficult_has_it_been_for_you_to_find_groceries_and_other_items'].value_counts()
# Out:
# 3    179712
# 4    100392
# 2     71438
# 5     41827
# 1     26727
# Name: how_difficult_has_it_been_for_you_to_find_groceries_and_other_items, dtype: int64

# %%
data_Phi.head(3)
# Out:
#             campaign_name        project_id project_name organization_id  \
# 13995  ph_covid-19-impact  6055346049384448     COVID-19         premise
# 13996  ph_covid-19-impact  6055346049384448     COVID-19         premise
# 13997  ph_covid-19-impact  6055346049384448     COVID-19         premise
#
#        gender                 age geography  \
# 13995  Female  26 to 35 years old     Rural
# 13996  Female  26 to 35 years old     Rural
# 13997    Male            Under 16     Rural
#
#                                      financial_situation  \
# 13995                I can afford food, but nothing else
# 13996  I can afford food and regular expenses, and bu...
# 13997                I can afford food, but nothing else
#
#                    education   employment_status ethnicity      religion  \
# 13995       Technical school  Employed full-time    Bisaya  Christianity
# 13996  College or university  Employed full-time    Bisaya  Christianity
# ...

# %%
data_Phi['have_you_or_a_family_member_been_affected_by_price_gouging_for_goods_and_services_related_to_the_coronavirus_covid_19'].value_counts()
# Out:
# Minor effect       120146
# Major effect        89474
# Unsure              78007
# Moderate effect     77379
# No effect           55090
# Name: have_you_or_a_family_member_been_affected_by_price_gouging_for_goods_and_services_related_to_the_coronavirus_covid_19, dtype: int64

# %%
scale_4 = {'Major effect':5,
          'Moderate effect':4,
          'Unsure':3,
          'Minor effect':2,
          'No effect':1}
data_Phi['have_you_or_a_family_member_been_affected_by_price_gouging_for_goods_and_services_related_to_the_coronavirus_covid_19']=data_Phi['have_you_or_a_family_member_been_affected_by_price_gouging_for_goods_and_services_related_to_the_coronavirus_covid_19'].replace(scale_4)
# Out:
# <ipython-input-42-6c111d0fa2af>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Phi['have_you_or_a_family_member_been_affected_by_price_gouging_for_goods_and_services_related_to_the_coronavirus_covid_19']=data_Phi['have_you_or_a_family_member_been_affected_by_price_gouging_for_goods_and_services_related_to_the_coronavirus_covid_19'].replace(scale_4)

# %%
data_Phi['have_you_or_a_family_member_been_affected_by_price_gouging_for_goods_and_services_related_to_the_coronavirus_covid_19'].value_counts()
# Out:
# 2    120146
# 5     89474
# 3     78007
# 4     77379
# 1     55090
# Name: have_you_or_a_family_member_been_affected_by_price_gouging_for_goods_and_services_related_to_the_coronavirus_covid_19, dtype: int64
