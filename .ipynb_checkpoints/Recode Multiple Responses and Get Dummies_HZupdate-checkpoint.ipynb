# %%
import numpy as np 
import pandas as pd 
from datetime import datetime, date, time
from datetime import timedelta
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
# %matplotlib inline
import seaborn as sns


# set float display default
pd.set_option('display.float_format', lambda x: '%.2f' % x)

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv("covid_with_factors.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-71d94f9f11a5> in <module>
# ----> 1 df = pd.read_csv("covid_with_factors.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
df.head()
# Out:
#   gender                 age            geography  \
# 0   Male  16 to 25 years old                Rural
# 1   Male  16 to 25 years old                Rural
# 2   Male  16 to 25 years old                Rural
# 3   Male  16 to 25 years old  Suburban/Peri-urban
# 4   Male  16 to 25 years old                Rural
#
#                                                                          financial_situation  \
# 0                                   I can afford food and regular expenses, but nothing else
# 1  I can afford food and regular expenses, and buy new clothes once a year, but nothing else
# 2                                   I can afford food and regular expenses, but nothing else
# 3                                   I can afford food and regular expenses, but nothing else
# 4                                                        I can afford food, but nothing else
#
#                education   employment_status         ethnicity  \
# ...

# %%
column_values = df.apply(lambda x: len(x.unique()))
column_values[column_values >10]
# Out:
# ethnicity                                                                                                                                                                  234
# religion                                                                                                                                                                    52
# batch_date                                                                                                                                                                 126
# observation_lat                                                                                                                                                          74643
# observation_lon                                                                                                                                                         125137
# ...

# %%
mult_responses = column_values[column_values >10].loc["what_kind_of_locations_or_facilities_are_offering_testing_in_your_city":"which_media_outlets_do_you_think_only_report_on_the_potential_disadvantages_of_a_covid_19_vaccine"]
print(mult_responses)
# Out:
# what_kind_of_locations_or_facilities_are_offering_testing_in_your_city                                                                                                    256
# which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open                                                129
# which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find                                                                                           512
# from_which_of_the_following_places_have_you_purchased_or_looked_for_food_and_other_supplies                                                                                64
# which_of_the_following_factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing                                                                   64
# ...

# %% [markdown]
# ## Q1

# %%
df['what_kind_of_locations_or_facilities_are_offering_testing_in_your_city'].value_counts()
#.sort_values(ascending=False)
# Out:
# My primary care physician’s office                                                     267368
# Hospital                                                                               237893
# Local health department                                                                159236
# Drive-up testing facility                                                               96574
# Drive-up testing facility^My primary care physician’s office                            39372
#                                                                                         ...
# Drive-up testing facility^Emergency room^Other^Pharmacy^Urgent care clinic                  3
# Emergency room^My primary care physician’s office^Other^Pharmacy^Urgent care clinic         3
# Drive-up testing facility^Emergency room^Local health department^Other^Pharmacy             2
# Drive-up testing facility^Emergency room^Other^Pharmacy                                     2
# ...

# %% [markdown]
# what_kind_of_locations_or_facilities_are_offering_testing_in_your_city?
# + My primary care physicians office
# + Drive-up testing facility
# + Local health department
# + Urgent care clinic
# + Pharmacy
# + Emergency room
# + Hospital
# + Other

# %%
#df['locations_offering_testing_in_your_city_My_primary_care_physicians_office'] = df["what_kind_of_locations_or_facilities_are_offering_testing_in_your_city"].str.contains("My primary care physician", regex=False, na=False).astype(int)
#this is changing the name of the column in the data frame from what kind of locations to my primary care physicians office

# %%
df['locations_offering_testing_in_your_city_My_primary_care_physicians_office'] = df["what_kind_of_locations_or_facilities_are_offering_testing_in_your_city"].str.contains("My primary care physician", regex=False, na=False).astype(int)
df['locations_offering_testing_in_your_city_Drive_up_testing_facility'] = df["what_kind_of_locations_or_facilities_are_offering_testing_in_your_city"].str.contains("Drive-up testing facility", regex=False, na=False).astype(int)
df['locations_offering_testing_in_your_city_Local_health_department'] = df["what_kind_of_locations_or_facilities_are_offering_testing_in_your_city"].str.contains("Local health department", regex=False, na=False).astype(int)
df['locations_offering_testing_in_your_city_Urgent_care_clinic'] = df["what_kind_of_locations_or_facilities_are_offering_testing_in_your_city"].str.contains("Urgent care clinic", regex=False, na=False).astype(int)
df['locations_offering_testing_in_your_city_Pharmacy'] = df["what_kind_of_locations_or_facilities_are_offering_testing_in_your_city"].str.contains("Pharmacy", regex=False, na=False).astype(int)
df['locations_offering_testing_in_your_city_Emergency_room'] = df["what_kind_of_locations_or_facilities_are_offering_testing_in_your_city"].str.contains("Emergency room", regex=False, na=False).astype(int)
df['locations_offering_testing_in_your_city_Hospital'] = df["what_kind_of_locations_or_facilities_are_offering_testing_in_your_city"].str.contains("Hospital", regex=False, na=False).astype(int)
df['locations_offering_testing_in_your_city_Other'] = df["what_kind_of_locations_or_facilities_are_offering_testing_in_your_city"].str.contains("Other", regex=False, na=False).astype(int)

# %%
check_cols = [col for col in df.columns if 'offering_testing_in_your_city' in col]
print(check_cols)
# Out:
# ['what_kind_of_locations_or_facilities_are_offering_testing_in_your_city', 'locations_offering_testing_in_your_city_My_primary_care_physicians_office', 'locations_offering_testing_in_your_city_Drive_up_testing_facility', 'locations_offering_testing_in_your_city_Local_health_department', 'locations_offering_testing_in_your_city_Urgent_care_clinic', 'locations_offering_testing_in_your_city_Pharmacy', 'locations_offering_testing_in_your_city_Emergency_room', 'locations_offering_testing_in_your_city_Hospital', 'locations_offering_testing_in_your_city_Other']

# %%
df[check_cols][~df["what_kind_of_locations_or_facilities_are_offering_testing_in_your_city"].isnull()]
# Out:
#                                           what_kind_of_locations_or_facilities_are_offering_testing_in_your_city  \
# 0                                                                                                       Hospital
# 3                                                                                      Drive-up testing facility
# 4                                                     Local health department^My primary care physician’s office
# 7        Drive-up testing facility^Local health department^My primary care physician’s office^Urgent care clinic
# 9                                                                                                       Hospital
# ...                                                                                                          ...
# 2866976                                                                                  Local health department
# ...

# %%
cols = [col for col in df.columns if 'locations_offering_testing_in_your_city' in col]
cols
# Out:
# ['locations_offering_testing_in_your_city_My_primary_care_physicians_office',
#  'locations_offering_testing_in_your_city_Drive_up_testing_facility',
#  'locations_offering_testing_in_your_city_Local_health_department',
#  'locations_offering_testing_in_your_city_Urgent_care_clinic',
#  'locations_offering_testing_in_your_city_Pharmacy',
#  'locations_offering_testing_in_your_city_Emergency_room',
#  'locations_offering_testing_in_your_city_Hospital',
#  'locations_offering_testing_in_your_city_Other']

# %%
location_means=df[cols][~df["what_kind_of_locations_or_facilities_are_offering_testing_in_your_city"].isnull()].mean()
location_means
# Out:
# locations_offering_testing_in_your_city_My_primary_care_physicians_office   0.40
# locations_offering_testing_in_your_city_Drive_up_testing_facility           0.25
# locations_offering_testing_in_your_city_Local_health_department             0.35
# locations_offering_testing_in_your_city_Urgent_care_clinic                  0.17
# locations_offering_testing_in_your_city_Pharmacy                            0.07
# locations_offering_testing_in_your_city_Emergency_room                      0.13
# locations_offering_testing_in_your_city_Hospital                            0.41
# locations_offering_testing_in_your_city_Other                               0.04
# dtype: float64

# %% [markdown]
# ### Q2

# %%
df['which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open'].value_counts().sort_values(ascending=False)
# Out:
# did not exist                                                                                                                                                                                       321897
# Visiting a friend’s home for a small social gathering (fewer than 10 people)                                                                                                                        314932
# Shopping at non-essential stores                                                                                                                                                                    170062
# None of the above                                                                                                                                                                                   159090
# ...

# %% [markdown]
# 'which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open
#
# + Visiting a friend's home for a small social gathering (fewer than 10 people)
# + Shopping at non-essential stores
# + Going out to bars and restaurants
# + Seeing movies at the movie theater
# + Riding public transportation
# + Traveling by airplane
# + None of the above

# %%
df['activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Visiting_a_friends_home_fewer_than_10']=df['which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open'].str.contains("Visiting a friend’s home for a small social gathering (fewer than 10 people)", regex=False, na=False).astype(int)
df['activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Shopping_at_non-essential_stores']=df['which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open'].str.contains('Shopping at non-essential stores', regex=False, na=False).astype(int)
df['activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Going_out_to_bars_and_restaurants']=df['which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open'].str.contains('Going out to bars and restaurants', regex=False, na=False).astype(int)
df['activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Seeing_movies_at_the_movie_theatre']=df['which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open'].str.contains('Seeing movies at the movie theater', regex=False, na=False).astype(int)
df['activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Riding_public_transportation']=df['which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open'].str.contains('Riding public transportation', regex=False, na=False).astype(int)
df['activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Traveling_by_airplane']=df['which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open'].str.contains('Traveling by airplane', regex=False, na=False).astype(int)
df['activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_None_of_the_above']=df['which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open'].str.contains('None of the above', regex=False, na=False).astype(int)

# %%
check_cols = [col for col in df.columns if 'now_or_immediately_after_non_essential_businesses_re_open' in col]
print(check_cols)
# Out:
# ['which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open', 'activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Visiting_a_friends_home_fewer_than_10', 'activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Shopping_at_non-essential_stores', 'activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Going_out_to_bars_and_restaurants', 'activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Seeing_movies_at_the_movie_theatre', 'activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Riding_public_transportation', 'activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Traveling_by_airplane', 'activities_will_you_feel_comfortable_with_now_or_immediately_
# ...

# %%
df[check_cols][~df['which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open'].isnull()]
# Out:
#                                                              which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open  \
# 0                                                                                                          Visiting a friend’s home for a small social gathering (fewer than 10 people)
# 5                                                                                                          Visiting a friend’s home for a small social gathering (fewer than 10 people)
# 6        Going out to bars and restaurants^Riding public transportation^Seeing movies at the movie theater^Visiting a friend’s home for a small social gathering (fewer than 10 people)
# 7                                                                                 Going out to bars and restaurants^Seeing movies at the movie theater^Shopping at non-essential stores
# ...

# %%
cols= [col for col in df.columns if 'activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open' in col]
cols= cols[1:]
cols
# Out:
# ['activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Visiting_a_friends_home_fewer_than_10',
#  'activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Shopping_at_non-essential_stores',
#  'activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Going_out_to_bars_and_restaurants',
#  'activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Seeing_movies_at_the_movie_theatre',
#  'activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Riding_public_transportation',
#  'activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Traveling_by_airplane',
#  'activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_None_of_the_above']

# %%
activity_means = df[cols][(~df['which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open'].isnull()) & (df['which_of_the_following_activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open'] != 'did not exist')].mean()        
activity_means
# Out:
# activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Visiting_a_friends_home_fewer_than_10   0.56
# activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Shopping_at_non-essential_stores        0.43
# activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Going_out_to_bars_and_restaurants       0.18
# activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Seeing_movies_at_the_movie_theatre      0.10
# activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Riding_public_transportation            0.14
# activities_will_you_feel_comfortable_with_now_or_immediately_after_non_essential_businesses_re_open_Traveling_by_airplane                   0.06
# ...

# %% [markdown]
# ### Q3
# Which of the following behaviors are you or do you expect to demonstrate in public once non-essential businesses re-open?
#
# + Maintaining physical distance from others
# + Wearing a face mask in public
# + Wearing gloves in public
# + Avoiding public places
# + Avoiding handshakes
# + Frequently washing hands
# + None of the above

# %%
df['which_of_the_following_behaviors_are_you_or_do_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open'].value_counts()
# Out:
# did not exist                                                                                                                                                           321897
# Wearing a face mask in public                                                                                                                                           210728
# Maintaining physical distance from others                                                                                                                               173687
# Avoiding handshakes^Avoiding public places^Frequently washing hands^Maintaining physical distance from others^Wearing a face mask in public                             135248
# Avoiding handshakes^Avoiding public places^Frequently washing hands^Maintaining physical distance from others^Wearing a face mask in public^Wearing gloves in public    119688
# ...

# %%
df['behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_maintaing_physical_distance']= df['which_of_the_following_behaviors_are_you_or_do_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open'].str.contains('Maintaining physical distance from others', regex=False, na=False).astype(int)
df['behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_wearing_face_mask']= df['which_of_the_following_behaviors_are_you_or_do_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open'].str.contains('Wearing a face mask in public', regex=False, na=False).astype(int)
df['behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_wearing_gloves'] =df['which_of_the_following_behaviors_are_you_or_do_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open'].str.contains('Wearing gloves in public', regex=False, na=False).astype(int)
df['behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_avoiding_public_places'] =df['which_of_the_following_behaviors_are_you_or_do_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open'].str.contains('Avoiding public places', regex=False, na=False).astype(int)
df['behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_avoiding_hand_shakes']= df['which_of_the_following_behaviors_are_you_or_do_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open'].str.contains('Avoiding handshakes', regex=False, na=False).astype(int)
df['behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_frequently_washing_hands']= df['which_of_the_following_behaviors_are_you_or_do_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open'].str.contains('Frequently washing hands', regex=False, na=False).astype(int)
df['behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_none_of_the_above'] =df['which_of_the_following_behaviors_are_you_or_do_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open'].str.contains('None of the above', regex=False, na=False).astype(int)

# %%
check_cols = [col for col in df.columns if 'you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open' in col]
print(check_cols)
# Out:
# ['which_of_the_following_behaviors_are_you_or_do_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open', 'behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_maintaing_physical_distance', 'behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_wearing_face_mask', 'behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_wearing_gloves', 'behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_avoiding_public_places', 'behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_avoiding_hand_shakes', 'behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_frequently_washing_hands', 'behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_none_of_the_above']

# %%
df[check_cols][~df['which_of_the_following_behaviors_are_you_or_do_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open'].isnull()]
# Out:
#         which_of_the_following_behaviors_are_you_or_do_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open  \
# 0                  Avoiding handshakes^Avoiding public places^Frequently washing hands^Maintaining physical distance from others
# 5                                                                                                  Wearing a face mask in public
# 6             Avoiding handshakes^Avoiding public places^Maintaining physical distance from others^Wearing a face mask in public
# 7                               Maintaining physical distance from others^Wearing a face mask in public^Wearing gloves in public
# 8                                                     Avoiding handshakes^Frequently washing hands^Wearing a face mask in public
# ...                                                                                                                          ...
# ...

# %%
cols = [col for col in df.columns if 'behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open' in col]

# %%
behavior_means = df[cols][(~df['which_of_the_following_behaviors_are_you_or_do_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open'].isnull()) & (df['which_of_the_following_behaviors_are_you_or_do_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open']!='did not exist')].mean()
behavior_means
# Out:
# behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_maintaing_physical_distance   0.68
# behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_wearing_face_mask             0.75
# behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_wearing_gloves                0.26
# behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_avoiding_public_places        0.33
# behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_avoiding_hand_shakes          0.36
# behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_frequently_washing_hands      0.38
# behaviors_you_expect_to_demonstrate_in_public_once_non_essential_businesses_re_open_none_of_the_above             0.01
# dtype: float64

# %% [markdown]
# ### Q4
#
# Which of the following categories of items were difficult or impossible to find?
#
# + Fresh produce
# + Fresh meats
# + Canned goods
# + Frozen goods
# + Other pre-packaged goods
# + Cleaning supplies
# + Toilet paper
# + Over-the-counter medicines or medical supplies
# + Other

# %%
df['which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find'].value_counts().sort_values(ascending=False)
# Out:
# Fresh produce                                                                                                            277723
# Fresh meats                                                                                                              128655
# Fresh meats^Fresh produce                                                                                                 74181
# Other                                                                                                                     50913
# Over-the-counter medicines or medical supplies                                                                            43620
#                                                                                                                           ...
# Canned goods^Fresh produce^Frozen goods^Other^Other pre-packaged goods^Toilet paper                                           2
# ...

# %%
df['categories_of_items_were_difficult_or_impossible_to_find_fresh_produce']=df['which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find'].str.contains("Fresh produce", regex=False, na=False).astype(int)
df['categories_of_items_were_difficult_or_impossible_to_find_fresh_meats']=df['which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find'].str.contains("Fresh meats", regex=False, na=False).astype(int)
df['categories_of_items_were_difficult_or_impossible_to_find_canned_goods']= df['which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find'].str.contains("Canned goods", regex=False, na=False).astype(int)
df['categories_of_items_were_difficult_or_impossible_to_find_frozen_goods']= df['which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find'].str.contains("Frozen goods", regex=False, na=False).astype(int)
df['categories_of_items_were_difficult_or_impossible_to_find_pre_pack_goods']=df['which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find'].str.contains("Other pre-packaged goods", regex=False, na=False).astype(int)
df['categories_of_items_were_difficult_or_impossible_to_find_cleaning_sup'] =df['which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find'].str.contains("Cleaning supplies", regex=False, na=False).astype(int)
df['categories_of_items_were_difficult_or_impossible_to_find_toilet_pap'] =df['which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find'].str.contains("Toilet paper", regex=False, na=False).astype(int)
df['categories_of_items_were_difficult_or_impossible_to_find_over_the_counter_medical_sup']= df['which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find'].str.contains("Over-the-counter medicines or medical supplies", regex=False, na=False).astype(int)
df['categories_of_items_were_difficult_or_impossible_to_find_other']= df['which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find'].str.contains(r"Other(?!\s)", regex=True, na=False).astype(int)

# %%
check_cols = [col for col in df.columns if 'items_were_difficult_or_impossible_to_find' in col]
print(check_cols)
# Out:
# ['which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find', 'categories_of_items_were_difficult_or_impossible_to_find_fresh_produce', 'categories_of_items_were_difficult_or_impossible_to_find_fresh_meats', 'categories_of_items_were_difficult_or_impossible_to_find_canned_goods', 'categories_of_items_were_difficult_or_impossible_to_find_frozen_goods', 'categories_of_items_were_difficult_or_impossible_to_find_pre_pack_goods', 'categories_of_items_were_difficult_or_impossible_to_find_cleaning_sup', 'categories_of_items_were_difficult_or_impossible_to_find_toilet_pap', 'categories_of_items_were_difficult_or_impossible_to_find_over_the_counter_medical_sup', 'categories_of_items_were_difficult_or_impossible_to_find_other']

# %%
df[check_cols][~df['which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find'].isnull()]
# Out:
#                                         which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find  \
# 2        Fresh meats^Fresh produce^Frozen goods^Other pre-packaged goods^Over-the-counter medicines or medical supplies
# 3                                                                                                           Fresh meats
# 4                                                                                Canned goods^Fresh meats^Fresh produce
# 7                                                                   Canned goods^Fresh meats^Fresh produce^Frozen goods
# 13                                                                                                          Fresh meats
# ...                                                                                                                 ...
# 2866976                                                                                                   Fresh produce
# ...

# %%
cols= [col for col in df.columns if 'categories_of_items_were_difficult_or_impossible_to_find' in col]
cols = cols[1:]

# %%
category_means = df[cols][~df['which_of_the_following_categories_of_items_were_difficult_or_impossible_to_find'].isnull()].mean()
category_means
# Out:
# categories_of_items_were_difficult_or_impossible_to_find_fresh_produce                  0.57
# categories_of_items_were_difficult_or_impossible_to_find_fresh_meats                    0.42
# categories_of_items_were_difficult_or_impossible_to_find_canned_goods                   0.22
# categories_of_items_were_difficult_or_impossible_to_find_frozen_goods                   0.14
# categories_of_items_were_difficult_or_impossible_to_find_pre_pack_goods                 0.13
# categories_of_items_were_difficult_or_impossible_to_find_cleaning_sup                   0.16
# categories_of_items_were_difficult_or_impossible_to_find_toilet_pap                     0.11
# categories_of_items_were_difficult_or_impossible_to_find_over_the_counter_medical_sup   0.18
# categories_of_items_were_difficult_or_impossible_to_find_other                          0.08
# dtype: float64

# %% [markdown]
# ### Q5
# From which of the following places have you purchased or looked for food and other supplies?
#
# + Grocery stores or supermarkets |
# + Local markets |
# + Big box stores or hypermarkets (e.g. Target, Costco) |
# + Pharmacies |
# + Online (e.g. Amazon, Alibaba) |
# + Other

# %%
df['from_which_of_the_following_places_have_you_purchased_or_looked_for_food_and_other_supplies'].value_counts().sort_values(ascending=False)
# Out:
# Local markets                                                                                                                                       790170
# Grocery stores or supermarkets                                                                                                                      575063
# Grocery stores or supermarkets^Local markets                                                                                                        371800
# Big box stores or hypermarkets (e.g. Target, Costco)                                                                                                152797
# Big box stores or hypermarkets (e.g. Target, Costco)^Grocery stores or supermarkets^Local markets                                                   142529
# Grocery stores or supermarkets^Local markets^Pharmacies                                                                                             137849
# ...

# %%
df['places_you_have_looked_for_food_and_other_supplies_grocery_or_supermarket']=df['from_which_of_the_following_places_have_you_purchased_or_looked_for_food_and_other_supplies'].str.contains("Grocery stores or supermarkets", regex=False, na=False).astype(int)
df['places_you_have_looked_for_food_and_other_supplies_local_market']=df['from_which_of_the_following_places_have_you_purchased_or_looked_for_food_and_other_supplies'].str.contains("Local markets", regex=False, na=False).astype(int)
df['places_you_have_looked_for_food_and_other_supplies_big_box_hyper']=df['from_which_of_the_following_places_have_you_purchased_or_looked_for_food_and_other_supplies'].str.contains("Big bix stores or hypermarkets", regex=False, na=False).astype(int)
df['places_you_have_looked_for_food_and_other_supplies_pharmacies']=df['from_which_of_the_following_places_have_you_purchased_or_looked_for_food_and_other_supplies'].str.contains("Pharmacies", regex=False, na=False).astype(int)
df['places_you_have_looked_for_food_and_other_supplies_online']=df['from_which_of_the_following_places_have_you_purchased_or_looked_for_food_and_other_supplies'].str.contains("Online", regex=False, na=False).astype(int)
df['places_you_have_looked_for_food_and_other_supplies_other']=df['from_which_of_the_following_places_have_you_purchased_or_looked_for_food_and_other_supplies'].str.contains("Other", regex=False, na=False).astype(int)

# %%
check_cols = [col for col in df.columns if 'food_and_other_supplies' in col]
print(check_cols)
# Out:
# ['from_which_of_the_following_places_have_you_purchased_or_looked_for_food_and_other_supplies', 'places_you_have_looked_for_food_and_other_supplies_grocery_or_supermarket', 'places_you_have_looked_for_food_and_other_supplies_local_market', 'places_you_have_looked_for_food_and_other_supplies_big_box_hyper', 'places_you_have_looked_for_food_and_other_supplies_pharmacies', 'places_you_have_looked_for_food_and_other_supplies_online', 'places_you_have_looked_for_food_and_other_supplies_other']

# %%
df[check_cols][~df['from_which_of_the_following_places_have_you_purchased_or_looked_for_food_and_other_supplies'].isnull()]
# Out:
#                           from_which_of_the_following_places_have_you_purchased_or_looked_for_food_and_other_supplies  \
# 0                                                                                                       Local markets
# 1                                                                        Grocery stores or supermarkets^Local markets
# 2                                                             Grocery stores or supermarkets^Local markets^Pharmacies
# 3                                                                                                       Local markets
# 4                   Big box stores or hypermarkets (e.g. Target, Costco)^Grocery stores or supermarkets^Local markets
# ...                                                                                                               ...
# 2866980  Big box stores or hypermarkets (e.g. Target, Costco)^Grocery stores or supermarkets^Local markets^Pharmacies
# ...

# %%
cols = [col for col in df.columns if 'places_you_have_looked_for_food_and_other_supplies' in col]
cols
# Out:
# ['places_you_have_looked_for_food_and_other_supplies_grocery_or_supermarket',
#  'places_you_have_looked_for_food_and_other_supplies_local_market',
#  'places_you_have_looked_for_food_and_other_supplies_big_box_hyper',
#  'places_you_have_looked_for_food_and_other_supplies_pharmacies',
#  'places_you_have_looked_for_food_and_other_supplies_online',
#  'places_you_have_looked_for_food_and_other_supplies_other']

# %%
place_means= df[cols][~df['from_which_of_the_following_places_have_you_purchased_or_looked_for_food_and_other_supplies'].isnull()].mean()
place_means
# Out:
# places_you_have_looked_for_food_and_other_supplies_grocery_or_supermarket   0.56
# places_you_have_looked_for_food_and_other_supplies_local_market             0.66
# places_you_have_looked_for_food_and_other_supplies_big_box_hyper            0.00
# places_you_have_looked_for_food_and_other_supplies_pharmacies               0.19
# places_you_have_looked_for_food_and_other_supplies_online                   0.07
# places_you_have_looked_for_food_and_other_supplies_other                    0.04
# dtype: float64

# %% [markdown]
# ### Q6

# %% [markdown]
# how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase
# + Local newspaper (or its website) |
# + National newspaper (or its website) |
# + Local television station |
# + National or cable television station |
# + Local radio |
# + National radio |
# + Health Organizations (e.g. WHO, CDC, local health department)
# + Social media (e.g. Facebook, Twitter, Instagram, WhatsApp) |
# + Other

# %%
df['how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase'].value_counts().sort_values(ascending=False)
# Out:
# Local newspaper (or its website)                                                                                                                                        554015
# National newspaper (or its website)                                                                                                                                     344316
# Local television station                                                                                                                                                196183
# Local newspaper (or its website)^National newspaper (or its website)                                                                                                    183400
# Social media (e.g. Facebook, Twitter, Instagram, WhatsApp)                                                                                                              183200
# ...

# %%
df['types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_local_newspaper']=df['how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase'].str.contains("Local newspaper", regex=False, na=False).astype(int)
df['types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_national_newspaper']=df['how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase'].str.contains("National newspaper", regex=False, na=False).astype(int)
df['types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_local_television']=df['how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase'].str.contains("Local television station", regex=False, na=False).astype(int)
df['types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_national_television']=df['how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase'].str.contains("National or cable television station", regex=False, na=False).astype(int)
df['types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_local_radio']=df['how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase'].str.contains("Local radio", regex=False, na=False).astype(int)
df['types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_national_radio']=df['how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase'].str.contains("National radio", regex=False, na=False).astype(int)
df['types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_health_organizations']=df['how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase'].str.contains("Health Organizations", regex=False, na=False).astype(int)
df['types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_social_media']=df['how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase'].str.contains("Social media", regex=False, na=False).astype(int)
df['types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_other']=df['how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase'].str.contains("Other", regex=False, na=False).astype(int)

# %%
check_cols = [col for col in df.columns if 'types_of_media' in col]
print(check_cols)
# Out:
# ['how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase', 'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_local_newspaper', 'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_national_newspaper', 'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_local_television', 'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_national_television', 'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_local_radio', 'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_national_radio', 'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_health_organizations', 'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_social_media', 'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_other']

# %%
df[check_cols][~df['how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase'].isnull()]
# Out:
#                                                                                                                            how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase  \
# 0        Health Organizations (e.g. WHO, CDC, local health department)^Local newspaper (or its website)^Local radio^Local television station^National newspaper (or its website)^National or cable television station^National radio^Social media (e.g. Facebook, Twitter, Instagram, WhatsApp)
# 1                                                                                                                                                                                                 Local newspaper (or its website)^Local television station^National newspaper (or its website)
# ...

# %%
cols = [col for col in df.columns if 'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase' in col]
cols
# Out:
# ['types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_local_newspaper',
#  'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_national_newspaper',
#  'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_local_television',
#  'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_national_television',
#  'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_local_radio',
#  'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_national_radio',
#  'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_health_organizations',
#  'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_social_media',
#  'types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_other']

# %%
media_means=df[cols][~df['how_have_you_been_getting_updates_on_covid_19_from_the_list_below_select_all_the_types_of_media_youu2019ve_been_relying_on_for_updates_as_coronavirus_cases_increase'].isnull()].mean()
media_means
# Out:
# types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_local_newspaper        0.50
# types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_national_newspaper     0.44
# types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_local_television       0.36
# types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_national_television    0.26
# types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_local_radio            0.14
# types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_national_radio         0.12
# types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_health_organizations   0.18
# types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_social_media           0.31
# types_of_media_you_rely_on_for_updates_as_coronavirus_cases_increase_other                  0.03
# dtype: float64

# %% [markdown]
# ### Q7

# %% [markdown]
# which_of_the_following_factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing
# + I don't interact with people in the most vulnerable groups |
# + My work has not been supportive of social distancing measures |
# + I do not want to lose my employer-provided insurance |
# + I cannot avoid public trans
# + I cannot work from home |
# + Few people in my community are following social distancing guidance

# %%
df['which_of_the_following_factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing'].value_counts()
# Out:
# I don’t interact with people in the most vulnerable groups                                                                                                                                                                                                                                                        9637
# Few people in my community are following social distancing guidance                                                                                                                                                                                                                                               9592
# My work has not been supportive of social distancing measures                                                                                                                                                                                                                                                     8552
# ...

# %%
df['factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_dont_interact_with_most_vuln']=df['which_of_the_following_factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing'].str.contains("most vulnerable groups", regex=False, na=False).astype(int)
df['factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_work_is_not_supportive_of_social_distancing']=df['which_of_the_following_factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing'].str.contains("not been supportive of social distancing measures", regex=False, na=False).astype(int)
df['factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_do_not_want_to_lose_my_employer_provided_insurance']=df['which_of_the_following_factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing'].str.contains("I do not want to lose my employer-provided insurance", regex=False, na=False).astype(int)
df['factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_cant_avoid_pub_trans']=df['which_of_the_following_factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing'].str.contains("I cannot avoid public trans", regex=False, na=False).astype(int)
df['factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_cant_work_from_home']=df['which_of_the_following_factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing'].str.contains("I cannot work from home", regex=False, na=False).astype(int)
df['factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_few people_in_my_community_follow_social_distancing']=df['which_of_the_following_factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing'].str.contains("Few people in my community are following social distancing guidance", regex=False, na=False).astype(int)

# %%
check_cols = [col for col in df.columns if 'factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing' in col]
print(check_cols)
# Out:
# ['which_of_the_following_factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing', 'factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_dont_interact_with_most_vuln', 'factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_work_is_not_supportive_of_social_distancing', 'factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_do_not_want_to_lose_my_employer_provided_insurance', 'factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_cant_avoid_pub_trans', 'factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_cant_work_from_home', 'factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_few people_in_my_community_follow_social_distancing']

# %%
df[check_cols][~df['which_of_the_following_factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing'].isnull()]
# Out:
#                                                                                                                                                                                                                which_of_the_following_factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing  \
# 42       Few people in my community are following social distancing guidance^I cannot avoid public transportation^I cannot work from home^I do not want to lose my employer-provided insurance^I don’t interact with people in the most vulnerable groups^My work has not been supportive of social distancing measures
# 43                                                                                                                                                                                                                                                                 I do not want to lose my employer-provided insurance
# ...

# %%
cols=[col for col in df.columns if 'factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing' in col]
cols=cols[1:]

# %%
distance_mean = df[cols][~df['which_of_the_following_factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing'].isnull()].mean()
distance_mean
# Out:
# factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_dont_interact_with_most_vuln                          0.26
# factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_work_is_not_supportive_of_social_distancing           0.29
# factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_do_not_want_to_lose_my_employer_provided_insurance    0.24
# factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_cant_avoid_pub_trans                                  0.22
# factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_cant_work_from_home                                   0.16
# factors_have_inclined_you_to_not_closely_follow_the_guidance_of_social_distancing_few people_in_my_community_follow_social_distancing   0.21
# dtype: float64

# %% [markdown]
# which_media_outlets_do_you_think_only_report_on_the_potential_disadvantages_of_a_covid_19_vaccine

# %%
df['which_media_outlets_do_you_think_only_report_on_the_potential_disadvantages_of_a_covid_19_vaccine'].value_counts()
# this is an open text response. Will not use for now
# Out:
# did not exist                                   2732598
# tv                                                  848
# redes sociales                                      696
# facebook                                            572
# internet                                            555
#                                                  ...
# tra                                                   1
# aglomeracon                                           1
# apenas os honestos                                    1
# periodiamo amarillista y paginas sin sentido          1
# tin thời sự                                           1
# Name: which_media_outlets_do_you_think_only_report_on_the_potential_disadvantages_of_a_covid_19_vaccine, Length: 13703, dtype: int64

# %%
df.shape
# Out:
# (2866985, 130)

# %% [markdown]
# # Get Dummies for additional questions

# %%
# List of questions
other_questions_col =['why_do_you_not_wear_a_mask_when_you_leave_your_home','one_last_question_what_do_you_think_has_negatively_impacted_your_daily_life_most_because_of_covid_19',
                      'do_you_have_school_aged_children_living_in_your_household',
                      'has_their_school_closed_due_to_covid_19',
                      'what_do_you_think_of_the_decision_to_re_open_schools_in_your_area',
                      'have_you_canceled_or_altered_travel_plans_because_of_the_coronavirus_covid_19',
                      'have_you_been_practicing_social_distancing_when_you_leave_the_house',
                      'have_you_left_or_are_you_planning_to_leave_your_home_today',
                      'why_did_you_or_are_you_planning_to_leave_your_home_today',
                      'in_the_past_week_how_much_did_you_reduce_the_number_of_hours_worked_compared_to_a_typical_week',
                      'how_long_do_you_believe_it_will_take_for_your_income_to_reach_its_pre_covid_19_levels',
                      'how_long_do_you_believe_it_will_take_for_your_local_economy_to_rebound_to_its_pre_covid_19_status',
                      'when_do_you_anticipate_feeling_comfortable_shopping_at_non_essential_stores',
                      'when_do_you_anticipate_feeling_comfortable_shopping_at_nonessential_stores_copy',
                      'when_do_you_anticipate_feeling_comfortable_riding_public_transportation',
                      'when_do_you_anticipate_feeling_comfortable_traveling_by_airplane',
                      'which_of_the_following_statements_best_describes_your_attitude_towards_your_local_town_or_municipality_governmentu2019s_response_to_covid_19_my_local_government_hasu2026',
                      'do_you_trust_your_local_or_national_government_to_make_more_effective_decisions_regarding_covid_19',
                      'are_non_essential_businesses_in_your_area_closed',
                      'are_non_essential_businesses_closed_by_declaration_of_authorities_or_voluntarily',
                      'when_do_you_believe_non_essential_businesses_should_open_in_your_area',
                      'what_do_you_think_of_the_timing_of_the_decision_to_re_open_non_essential_businesses_in_your_area',
                      'do_you_know_if_testing_for_coronavirus_is_available_in_your_city',
                      'have_you_personally_contracted_covid_19',
                      'did_you_seek_medical_care_to_treat_covid_19']
len(other_questions_col)
# Out:
# 25

# %%
df= pd.get_dummies(df, columns=other_questions_col)
df.head()
# Out:
#   gender                 age            geography  \
# 0   Male  16 to 25 years old                Rural
# 1   Male  16 to 25 years old                Rural
# 2   Male  16 to 25 years old                Rural
# 3   Male  16 to 25 years old  Suburban/Peri-urban
# 4   Male  16 to 25 years old                Rural
#
#                                                                          financial_situation  \
# 0                                   I can afford food and regular expenses, but nothing else
# 1  I can afford food and regular expenses, and buy new clothes once a year, but nothing else
# 2                                   I can afford food and regular expenses, but nothing else
# 3                                   I can afford food and regular expenses, but nothing else
# 4                                                        I can afford food, but nothing else
#
#                education   employment_status         ethnicity  \
# ...

# %%
df.shape
# Out:
# (2866985, 238)

# %% [markdown]
# ## Filter for number of cases by country
#
# ### change the number as you see fit

# %%
country=df.L0_name.value_counts()

# %%
country[country >10000]
# Out:
# Philippines                         420096
# Afghanistan                         210989
# Venezuela                           120919
# Mali                                103844
# Brazil                              101269
# United States                        93238
# Indonesia                            87169
# Kenya                                86700
# Nigeria                              85140
# Burkina Faso                         83042
# Yemen                                80772
# Ethiopia                             77684
# Peru                                 68000
# Mexico                               67756
# Colombia                             67627
# Taiwan                               63170
# Tanzania                             54634
# Uganda                               51233
# Ukraine                              48322
# Thailand                             47234
# Tunisia                              44687
# Turkey                               42446
# ...

# %%
country[country>10000].index.nunique()
# Out:
# 52

# %%
country_select = country[country>10000].index
country_select
# Out:
# Index(['Philippines', 'Afghanistan', 'Venezuela', 'Mali', 'Brazil',
#        'United States', 'Indonesia', 'Kenya', 'Nigeria', 'Burkina Faso',
#        'Yemen', 'Ethiopia', 'Peru', 'Mexico', 'Colombia', 'Taiwan', 'Tanzania',
#        'Uganda', 'Ukraine', 'Thailand', 'Tunisia', 'Turkey', 'Benin', 'Ghana',
#        'Argentina', 'Mozambique', 'India', 'Spain',
#        'Democratic Republic of the Congo', 'Italy', 'Morocco', 'Côte d'Ivoire',
#        'Ecuador', 'Malaysia', 'Algeria', 'Cambodia', 'Iraq', 'Zambia', 'Egypt',
#        'El Salvador', 'Honduras', 'Chile', 'Zimbabwe', 'Vietnam', 'Guatemala',
#        'Rwanda', 'Panama', 'Serbia', 'Bangladesh', 'Dominican Republic',
#        'Liberia', 'Poland'],
#       dtype='object')

# %%
data = df[df.L0_name.isin(country_select)]

# %%
data
# Out:
#         gender                 age                         geography  \
# 0         Male  16 to 25 years old                             Rural
# 1         Male  16 to 25 years old                             Rural
# 2         Male  16 to 25 years old                             Rural
# 3         Male  16 to 25 years old               Suburban/Peri-urban
# 4         Male  16 to 25 years old                             Rural
# ...        ...                 ...                               ...
# 2866980   Male  16 to 25 years old                             Rural
# 2866981   Male  16 to 25 years old  City center or metropolitan area
# 2866982   Male  26 to 35 years old  City center or metropolitan area
# 2866983   Male  36 to 45 years old  City center or metropolitan area
# 2866984   Male  16 to 25 years old  City center or metropolitan area
#
#                                                                                financial_situation  \
# ...

# %% [markdown]
# ## Save data

# %%
data.to_csv("covid_recoded_data.csv", index=False)
